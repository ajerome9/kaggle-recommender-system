# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns

dn = '/Users/aa/lab/kaggle/couponpurchase/data/'

# %% [raw]
# - Stats on purchases and views
#     - Purchases per month - 12000 to 17000 purchases
#     - How many users buying per month - 6000 to 8000 users
#     - Views per month - 220K to 260K views
#     - How many users viewing per month - 8000 to 10000 users

# %% [markdown]
# ## user_list.csv
# 22873 users

# %%
users = pd.read_csv(dn+'common/user_list.csv', 
                    header=0, 
                    parse_dates=['REG_DATE', 'WITHDRAW_DATE'])

def add_col(df, cname, suffix, fn):
    df[cname+'_'+suffix] = df[cname].map(fn)

fn_yyyymm = lambda x: int('{year}{month:02d}'.format(year=x.year,month=x.month)) if x is not pd.NaT else -1
fn_dayofwk = lambda x: int('{day}'.format(day=x.dayofweek)) if x is not pd.NaT else -1
fn_hourofd = lambda x: int('{hour}'.format(hour=x.hour)) if x is not pd.NaT else -1

#add_col(users, 'REG_DATE', 'YYYYMM', fn_yyyymm)
#add_col(users, 'REG_DATE', 'DAYOFWK', fn_dayofwk)
#add_col(users, 'REG_DATE', 'HOUROFD', fn_hourofd)

#add_col(users, 'WITHDRAW_DATE', 'YYYYMM', fn_yyyymm)
#add_col(users, 'WITHDRAW_DATE', 'DAYOFWK', fn_dayofwk)
#add_col(users, 'WITHDRAW_DATE', 'HOUROFD', fn_hourofd)

users.head()

# %%
users.info()

# %% [markdown]
# #### REG_DATE

# %%
print('RegDt: Min={}, Max={}'.format(users['REG_DATE'].min(),
                                     users['REG_DATE'].max()))
print('WdDt : Min={}, Max={}'.format(users['WITHDRAW_DATE'].min(),
                                     users['WITHDRAW_DATE'].max()))

# %% [markdown]
# <u>How were registrations and withdrawals distributed over time</u>

# %%
users['REG_DATE_YYYYMM'].value_counts().sort_index().plot(kind='bar')

# %%
withdraw_not_minus = users.loc[users['WITHDRAW_DATE_YYYYMM']!=-1, ['WITHDRAW_DATE_YYYYMM']]
withdraw_not_minus['WITHDRAW_DATE_YYYYMM'].value_counts().sort_index().plot(kind='bar')

# %%
def print_date_dist(title, se, fn):
    wise = se.map(fn)
    print('\n'+title)
    print(wise.value_counts().sort_index())

def print_yearmonwise(title, se):
    print_date_dist(title, se, 
                    lambda x: int('{year}{month:02d}'.format(year=x.year,month=x.month)) if x is not pd.NaT else -1)

def print_weekdaywise(title, se):
    print_date_dist(title, se, 
                    lambda x: int('{day}'.format(day=x.dayofweek)) if x is not pd.NaT else -1)

def print_hourwise(title, se):
    print_date_dist(title, se, 
                    lambda x: int('{hour}'.format(hour=x.hour)) if x is not pd.NaT else -1)

# print_yearmonwise('Registrations-ByYearMon', regdt)
# print_yearmonwise('Withdrawals-ByYearMon', wddt)
# print_weekdaywise('Registrations-ByWeekday', regdt)
# print_weekdaywise('Withdrawals-ByWeekday', wddt)
# print_hourwise('Registrations-ByHourofday', regdt)
# print_hourwise('Withdrawals-ByHourofday', wddt)

# %% [markdown]
# <u>How were registrations/withdrawals distributed by day of week</u>
#
# Most registrations around Mon/Tue/Wed. Most withdrawals around Wed/Thu, least on Fri

# %%
# Monday=0, Sunday=6
fig, axes = plt.subplots(1,2)
sns.countplot(x='REG_DATE_DAYOFWK', data=users, order=range(0,7,1), ax=axes[0])
sns.countplot(x='WITHDRAW_DATE_DAYOFWK', data=users, order=range(0,7,1), ax=axes[1])

# %% [markdown]
# <u>How ware registrations/withdrawals distributed by hour of day</u>

# %%
fig, axes = plt.subplots(1,2)
sns.countplot(x='REG_DATE_HOUROFD', data=users, order=range(0,24,1), ax=axes[0])
sns.countplot(x='WITHDRAW_DATE_HOUROFD', data=users, order=range(0,24,1), ax=axes[1])

# %% [markdown]
# #### SEX_ID
# 52% males, 48% females. All users have SEX_ID entered.

# %%
print(users['SEX_ID'].value_counts())
print(len(users))

# %% [markdown]
# #### AGE
# Most customers around 30-55yrs old

# %%
print('Age: Min={}, Max={}'.format(users['AGE'].min(),
                                   users['AGE'].max()))
users['AGE'].hist(bins=30)

# %% [markdown]
# #### PREF_NAME
# All 47 prefectures in Japan can be found in the dataset

# %%
print(users['PREF_NAME'].describe())
print('All records (with/without PREF_NAME)', len(users['PREF_NAME']))
sns.countplot(x='PREF_NAME', data=users)

# %% [markdown]
# ## coupon_list_train.csv
#
# 19413 coupons in training set

# %%
cpn_train = pd.read_csv(dn+'train/coupon_list_train.csv', 
                    header=0, 
                    parse_dates=['DISPFROM', 'DISPEND', 'VALIDFROM', 'VALIDEND'])
cpn_train.head(2)
# Out:
#   CAPSULE_TEXT GENRE_NAME  PRICE_RATE  CATALOG_PRICE  DISCOUNT_PRICE  \
# 0          グルメ        グルメ          50           3000            1500
# 1          グルメ        グルメ          51           2080            1000
#
#              DISPFROM             DISPEND  DISPPERIOD  VALIDFROM   VALIDEND  \
# 0 2011-07-08 12:00:00 2011-07-09 12:00:00           1 2011-07-10 2011-12-08
# 1 2011-07-01 12:00:00 2011-07-02 12:00:00           1 2011-07-03 2011-12-04
#
#                  ...                 USABLE_DATE_THU  USABLE_DATE_FRI  \
# 0                ...                               1                0
# 1                ...                               1                1
#
#    USABLE_DATE_SAT  USABLE_DATE_SUN  USABLE_DATE_HOLIDAY  \
# 0                0                1                    1
# 1                1                1                    1
#
#    USABLE_DATE_BEFORE_HOLIDAY  large_area_name  ken_name  small_area_name  \
# 0                           0               関東       埼玉県               埼玉
# 1                           1               関東       千葉県               千葉
#
#                      COUPON_ID_hash
# 0  6b263844241eea98c5a97f1335ea82af
# 1  cc031f250e8bad1e24060263b9fc0ddd
#
# [2 rows x 24 columns]

# %%
cpn_train.describe()
# Out:
#          PRICE_RATE  CATALOG_PRICE  DISCOUNT_PRICE    DISPPERIOD  \
# count  19413.000000   19413.000000    19413.000000  19413.000000
# mean      58.478391   11818.368258     4332.877659      3.166950
# std       11.266571   16881.898880     5459.667448      1.346859
# min        0.000000       1.000000        0.000000      0.000000
# 25%       50.000000    3675.000000     1550.000000      2.000000
# 50%       53.000000    6500.000000     2750.000000      3.000000
# 75%       65.000000   13650.000000     4800.000000      4.000000
# max      100.000000  680000.000000   100000.000000     36.000000
#
#         VALIDPERIOD  USABLE_DATE_MON  USABLE_DATE_TUE  USABLE_DATE_WED  \
# count  13266.000000     12408.000000     12408.000000     12408.000000
# mean     125.955902         0.936009         0.953901         0.982189
# std       46.599249         0.309854         0.314045         0.217525
# min        0.000000         0.000000         0.000000         0.000000
# 25%       89.000000         1.000000         1.000000         1.000000
# 50%      128.000000         1.000000         1.000000         1.000000
# 75%      177.000000         1.000000         1.000000         1.000000
# max      179.000000         2.000000         2.000000         2.000000
#
#        USABLE_DATE_THU  USABLE_DATE_FRI  USABLE_DATE_SAT  USABLE_DATE_SUN  \
# count     12408.000000     12408.000000     12408.000000     12408.000000
# mean          0.981867         1.000242         1.067618         0.921422
# std           0.198105         0.319562         0.563260         0.424181
# min           0.000000         0.000000         0.000000         0.000000
# 25%           1.000000         1.000000         1.000000         1.000000
# 50%           1.000000         1.000000         1.000000         1.000000
# 75%           1.000000         1.000000         1.000000         1.000000
# max           2.000000         2.000000         2.000000         2.000000
#
#        USABLE_DATE_HOLIDAY  USABLE_DATE_BEFORE_HOLIDAY
# count         12408.000000                12408.000000
# mean              0.938024                    1.044246
# std               0.399619                    0.534511
# min               0.000000                    0.000000
# 25%               1.000000                    1.000000
# 50%               1.000000                    1.000000
# 75%               1.000000                    1.000000
# max               2.000000                    2.000000

# %%
cpn_train.USABLE_DATE_BEFORE_HOLIDAY.value_counts()

# %%
cpn_train[cpn_train.COUPON_ID_hash=='6d0a997acf143496aa621867244efac7']
# Out:
#       CAPSULE_TEXT GENRE_NAME  PRICE_RATE  CATALOG_PRICE  DISCOUNT_PRICE  \
# 18874          その他   その他のクーポン          90           1000             100
#
#                  DISPFROM             DISPEND  DISPPERIOD  VALIDFROM  \
# 18874 2012-06-19 12:00:00 2012-06-23 12:00:00           4 2012-06-26
#
#         VALIDEND                ...                 USABLE_DATE_THU  \
# 18874 2012-07-31                ...                             NaN
#
#        USABLE_DATE_FRI  USABLE_DATE_SAT  USABLE_DATE_SUN  USABLE_DATE_HOLIDAY  \
# 18874              NaN              NaN              NaN                  NaN
#
#        USABLE_DATE_BEFORE_HOLIDAY  large_area_name  ken_name  small_area_name  \
# 18874                         NaN               関東       東京都   新宿・高田馬場・中野・吉祥寺
#
#                          COUPON_ID_hash
# 18874  6d0a997acf143496aa621867244efac7
#
# [1 rows x 24 columns]

# %% [markdown]
# ## coupon_list_test.csv
# 310 coupons in test set

# %%
cpn_test = pd.read_csv(dn+'test/coupon_list_test.csv', 
                    header=0, 
                    parse_dates=['DISPFROM', 'DISPEND', 'VALIDFROM', 'VALIDEND'])
cpn_test.info()

# %% [markdown]
# ## coupon_visit_train.csv
# Browsing history of users during training period. 2.8 Mil rows

# %% [raw]
# See data-exploration-bigfile for actual data
#
# 2833180 entries
# Data columns (total 8 columns):
# PURCHASE_FLG           2833180 non-null int64
# I_DATE                 2833180 non-null datetime64[ns]
# PAGE_SERIAL            2833180 non-null int64
# REFERRER_hash          2833180 non-null object
# VIEW_COUPON_ID_hash    2833180 non-null object
# USER_ID_hash           2833180 non-null object
# SESSION_ID_hash        2833180 non-null object
# PURCHASEID_hash        122389 non-null object

# %% [markdown]
# Views per month

# %%
fn = lambda x: int('{year}{month:02d}'.format(year=x.year,month=x.month)) if x is not pd.NaT else -1
views.groupby(views.I_DATE.map(fn)).count()

# %% [markdown]
# Distinct users viewing per month

# %%
fn = lambda x: int('{year}{month:02d}'.format(year=x.year,month=x.month)) if x is not pd.NaT else -1
views.groupby(views.I_DATE.map(fn)).USER_ID_hash.nunique()

# %% [markdown]
# ## coupon_detail_train.csv
#
# Purchase log during training-set time period (not provided for test-set period).
# 168996 purchases

# %%
prch = pd.read_csv(dn+'train/coupon_detail_train.csv', 
                    header=0, 
                    parse_dates=['I_DATE'])
prch.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 168996 entries, 0 to 168995
# Data columns (total 6 columns):
# ITEM_COUNT         168996 non-null int64
# I_DATE             168996 non-null datetime64[ns]
# SMALL_AREA_NAME    168996 non-null object
# PURCHASEID_hash    168996 non-null object
# USER_ID_hash       168996 non-null object
# COUPON_ID_hash     168996 non-null object
# dtypes: datetime64[ns](1), int64(1), object(4)
# memory usage: 9.0+ MB

# %%
prch.head()

# %%
for i, p in enumerate(prch.index):
    area_sa = area_train[area_train.COUPON_ID_hash==prch.iloc[p].COUPON_ID_hash].SMALL_AREA_NAME.values
    prch_sa = prch.iloc[p].SMALL_AREA_NAME
    cond = prch_sa in area_sa.tolist()
    if not cond:
        print('\n=============================')
        print(str(i+1)+'. Coupon Id:', prch.iloc[p].COUPON_ID_hash)
        print('Bought by:', prch.iloc[p].USER_ID_hash)
        print('---- Purchases:SmallAreaName ----')
        print(prch.iloc[p].SMALL_AREA_NAME)
        print('---- Users:PrefName ----')
        print(users[users.USER_ID_hash==prch.iloc[p].USER_ID_hash].PREF_NAME.values)
        print('---- Coupons:MerchantSmallArea ----')
        print(cpn_train[cpn_train.COUPON_ID_hash==prch.iloc[p].COUPON_ID_hash].small_area_name.values)
        print('---- Areas:ListingSmallArea ----')
        print(area_train[area_train.COUPON_ID_hash==prch.iloc[p].COUPON_ID_hash].SMALL_AREA_NAME.values)

# %%
tmp = prch.groupby('USER_ID_hash').count()['PURCHASEID_hash']
tmp = tmp.copy()
tmp.sort(ascending=False)
tmp.hist(bins=20)

# %%
prch.groupby('USER_ID_hash').count()
# Out:
#                                   ITEM_COUNT  I_DATE  SMALL_AREA_NAME  \
# USER_ID_hash
# 0000b53e182165208887ba65c079fc21           1       1                1
# 00035b86e6884589ec8d28fbf2fe7757           1       1                1
# 0005b1068d5f2b8f2a7c978fcfe1ca06           2       2                2
# 000cc06982785a19e2a2fdb40b1c9d59          21      21               21
# 0013518e41c416cd6a181d277dd8ca0b           4       4                4
# 001acdee812a18acfd7509172bed5700          13      13               13
# 001fd7876e3aa29393537c6baf308e43           1       1                1
# 002383753c1e5d6305c8aff6f89e26d6           1       1                1
# 0025cae7997d25ea5cf8851bb099c798           9       9                9
# 002822059a01d895fad84f2f2ff5c1f1           2       2                2
# 002ae30377cd30f65652e52618e8b2d6          12      12               12
# 002b08971471e6083dd716f6c3bb6572           4       4                4
# 002bbdd51b2a042c051c66c43b55439a           4       4                4
# 002f5c29fdf99b4115bf4a93c9241d19           1       1                1
# 003a7b4941222b7e507fdc9e95de2cc1           7       7                7
# 003e02424d0a6ec3ee80d231939fac7c           4       4                4
# 0042fc64a751d0b98e9148e3c366d319           6       6                6
# 00441c9b51cfe60b82bdf7a20ad79fc8          14      14               14
# 00454d0ad87f2e423cc3cc201fde8c8c           1       1                1
# 0047658498c5026a2bfa33b6f0573766           4       4                4
# 0047a9d43268c7cddf4a874c3dbb6f9f           2       2                2
# 004c5867575223ca7d7d3de4e8e1e23a           3       3                3
# 004d75de304e67612ec60e675af66839          14      14               14
# 004e1508270f3c9a0eb3cdfe89470c12           1       1                1
# 004e3f8a3635f9a0144771feaf8a1e32           1       1                1
# 004f67d329e3e56adef98c9aa8074e97           1       1                1
# 004f6fe912f2fa81036a47204eb69451           1       1                1
# 0051705e1aedf39d6c3019ef7a71d480          19      19               19
# 00563f5737892fc2f75f70bf794f4b43           1       1                1
# 0057e72575079113710648ae0f726d97          46      46               46
# ...                                      ...     ...              ...
# ffb4cb9419b6f156a2b26252aa0132ae          15      15               15
# ffb5c3ae7d5725689c74caebd44a8a62          18      18               18
# ffb688037381369f52268077d3941123          12      12               12
# ffb98d47f0b6bbf06cb1331e90a55179           3       3                3
# ffba61b78f71f7071830adba316031c2           9       9                9
# ffbd0b34af16015bebe4dfa99ab66621           2       2                2
# ffbd648c50a96cc493e960805b3bd30f           4       4                4
# ffbe59c00a8949be5ecc5f1ed871eae0          14      14               14
# ffc1ebba501d00aca267ce914e9e3110          61      61               61
# ffc76df6fa752ce7b49bb0ea4c97396d           1       1                1
# ffc7d9a1cf343d1246c047b6c1984454           4       4                4
# ffc9da5c3d1f082c50a120fe2be90913           1       1                1
# ffca89ec6ac84029fe7448e4e1c1adf6           1       1                1
# ffcd4d5b3682b27845c80ffc16c8c08b          25      25               25
# ffd5c4f2a415910b2bb96c0c68a1fcdd           1       1                1
# ffd6f660f3688968efa198ee888b1443           3       3                3
# ffd96bf2eb13fb10a2a5b3ed09f05f7b          10      10               10
# ffda28af997f586147eb23d612894e56           6       6                6
# ffdf3421c09fe158686523cea5e8ac39           1       1                1
# ffe3e44dab6fd47bd9c02782640c4d4a           9       9                9
# ffe65332382f1f264d84fa85a44f564c           2       2                2
# ffe7362865b91c287affaf8912ef4750           3       3                3
# ffecfec48a5778f3e470d8a4fb804723          14      14               14
# ffed1129803b26815be16d5531a27250           4       4                4
# fff193f946ae515d405376cdf7895f78           6       6                6
# fff1a623187cefd7a594e338709b0f40          14      14               14
# fff4a076cfda6ff9dbe85e1cb678791b          14      14               14
# fff970d2014c3e10a77e38d540239017           4       4                4
# fffafc024e264d5d539813444cf61199           2       2                2
# ffff56dbf3c782c3532f88c6c79817ba           3       3                3
#
#                                   PURCHASEID_hash  COUPON_ID_hash
# USER_ID_hash
# 0000b53e182165208887ba65c079fc21                1               1
# 00035b86e6884589ec8d28fbf2fe7757                1               1
# 0005b1068d5f2b8f2a7c978fcfe1ca06                2               2
# 000cc06982785a19e2a2fdb40b1c9d59               21              21
# 0013518e41c416cd6a181d277dd8ca0b                4               4
# 001acdee812a18acfd7509172bed5700               13              13
# 001fd7876e3aa29393537c6baf308e43                1               1
# 002383753c1e5d6305c8aff6f89e26d6                1               1
# 0025cae7997d25ea5cf8851bb099c798                9               9
# 002822059a01d895fad84f2f2ff5c1f1                2               2
# 002ae30377cd30f65652e52618e8b2d6               12              12
# 002b08971471e6083dd716f6c3bb6572                4               4
# 002bbdd51b2a042c051c66c43b55439a                4               4
# 002f5c29fdf99b4115bf4a93c9241d19                1               1
# 003a7b4941222b7e507fdc9e95de2cc1                7               7
# 003e02424d0a6ec3ee80d231939fac7c                4               4
# 0042fc64a751d0b98e9148e3c366d319                6               6
# 00441c9b51cfe60b82bdf7a20ad79fc8               14              14
# 00454d0ad87f2e423cc3cc201fde8c8c                1               1
# 0047658498c5026a2bfa33b6f0573766                4               4
# 0047a9d43268c7cddf4a874c3dbb6f9f                2               2
# 004c5867575223ca7d7d3de4e8e1e23a                3               3
# 004d75de304e67612ec60e675af66839               14              14
# 004e1508270f3c9a0eb3cdfe89470c12                1               1
# 004e3f8a3635f9a0144771feaf8a1e32                1               1
# 004f67d329e3e56adef98c9aa8074e97                1               1
# 004f6fe912f2fa81036a47204eb69451                1               1
# 0051705e1aedf39d6c3019ef7a71d480               19              19
# 00563f5737892fc2f75f70bf794f4b43                1               1
# 0057e72575079113710648ae0f726d97               46              46
# ...                                           ...             ...
# ffb4cb9419b6f156a2b26252aa0132ae               15              15
# ffb5c3ae7d5725689c74caebd44a8a62               18              18
# ffb688037381369f52268077d3941123               12              12
# ffb98d47f0b6bbf06cb1331e90a55179                3               3
# ffba61b78f71f7071830adba316031c2                9               9
# ffbd0b34af16015bebe4dfa99ab66621                2               2
# ffbd648c50a96cc493e960805b3bd30f                4               4
# ffbe59c00a8949be5ecc5f1ed871eae0               14              14
# ffc1ebba501d00aca267ce914e9e3110               61              61
# ffc76df6fa752ce7b49bb0ea4c97396d                1               1
# ffc7d9a1cf343d1246c047b6c1984454                4               4
# ffc9da5c3d1f082c50a120fe2be90913                1               1
# ffca89ec6ac84029fe7448e4e1c1adf6                1               1
# ffcd4d5b3682b27845c80ffc16c8c08b               25              25
# ffd5c4f2a415910b2bb96c0c68a1fcdd                1               1
# ffd6f660f3688968efa198ee888b1443                3               3
# ffd96bf2eb13fb10a2a5b3ed09f05f7b               10              10
# ffda28af997f586147eb23d612894e56                6               6
# ffdf3421c09fe158686523cea5e8ac39                1               1
# ffe3e44dab6fd47bd9c02782640c4d4a                9               9
# ffe65332382f1f264d84fa85a44f564c                2               2
# ffe7362865b91c287affaf8912ef4750                3               3
# ffecfec48a5778f3e470d8a4fb804723               14              14
# ffed1129803b26815be16d5531a27250                4               4
# fff193f946ae515d405376cdf7895f78                6               6
# fff1a623187cefd7a594e338709b0f40               14              14
# fff4a076cfda6ff9dbe85e1cb678791b               14              14
# fff970d2014c3e10a77e38d540239017                4               4
# fffafc024e264d5d539813444cf61199                2               2
# ffff56dbf3c782c3532f88c6c79817ba                3               3
#
# [22782 rows x 5 columns]

# %%
len(prch.USER_ID_hash.unique())

# %% [markdown]
# YearMonth-wise purchases

# %%
fn = lambda x: int('{year}{month:02d}'.format(year=x.year,month=x.month)) if x is not pd.NaT else -1
wise = prch.I_DATE.map(fn)
wise.value_counts().sort_index().plot(kind='bar')

# %% [markdown]
# Number of users purchasing per month

# %%
fn = lambda x: int('{year}{month:02d}'.format(year=x.year,month=x.month)) if x is not pd.NaT else -1
prch.groupby(purchases.I_DATE.map(fn)).USER_ID_hash.nunique()

# %% [markdown]
# ## coupon_area_train.csv
#
# coupon listing area for the training set coupons.
# 138185 rows

# %%
area_train = pd.read_csv(dn+'train/coupon_area_train.csv', 
                    header=0)
print(area_train.info())
area_train.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 138185 entries, 0 to 138184
# Data columns (total 3 columns):
# SMALL_AREA_NAME    138185 non-null object
# PREF_NAME          138185 non-null object
# COUPON_ID_hash     138185 non-null object
# dtypes: object(3)
# memory usage: 4.2+ MB
# None
#   SMALL_AREA_NAME PREF_NAME                    COUPON_ID_hash
# 0              埼玉       埼玉県  6b263844241eea98c5a97f1335ea82af
# 1              千葉       千葉県  cc031f250e8bad1e24060263b9fc0ddd
# 2              千葉       千葉県  ba5e9b7453ca52ff711635a5d2e8102d
# 3              千葉       千葉県  3e1ffbedca3569f9e8032d401e8cb4e6
# 4              千葉       千葉県  782934b6c815b4030ea204eef7d4a734

# %%
len(area_train.COUPON_ID_hash.unique())

# %% [markdown]
# ## coupon_area_test.csv
#
# coupon listing area for the test set coupons.
# 2165 rows

# %%
area_test = pd.read_csv(dn+'test/coupon_area_test.csv', 
                    header=0)
print(area_test.info())
area_test.head()

# %%
len(area_test.COUPON_ID_hash.unique())

# %% [markdown]
# ## prefecture_locations.csv

# %%
prfctr_loc = pd.read_csv(dn+'common/prefecture_locations.csv', 
                         header=0, encoding='utf-8-sig')
print(prfctr_loc.info())
prfctr_loc.head()

# %%
print(prfctr_loc.LATITUDE.describe())
print(prfctr_loc.LONGITUDE.describe())

# %% [markdown]
# ## sample_submission.csv

# %%
sample_subm = pd.read_csv(dn+'misc/sample_submission.csv', 
                    header=0)
print(sample_subm.info())
sample_subm.head()
